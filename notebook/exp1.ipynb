# %%
import pandas as pd 
import os 
from sqlalchemy import create_engine 
import logging
import time

# %%
# %pwd
# Out:
# 'c:\\Users\\6035s\\Desktop\\MLOPS\\Vendor-Performance-Analysis\\notebook'

# %%
import os 
os.chdir("../")

# %%
# %pwd
# Out:
# 'c:\\Users\\6035s\\Desktop\\MLOPS\\Vendor-Performance-Analysis'

# %%
# creating a database
engine = create_engine('sqlite:///inventory.db')

# %%
for file in os. listdir('data'): 
    print(file)
# Out:
# .ipynb_checkpoints
# begin_inventory.csv
# end_inventory.csv
# purchases.csv
# purchase_prices.csv
# sales.csv
# vendor_invoice.csv

# %%
# ingestion in to DB
for file in os. listdir('data'):
    for file in os. listdir('data'): 
        if '.csv' in file: 
            df = pd.read_csv('data/'+file) 
            print(df.shape)
            ingest_db(df, file[ :- 4], engine)

# %%
import os
import pandas as pd

# Assuming engine and ingest_db are already defined in your script

for file in os.listdir('data'): 
    # 1. Safely check if the file is actually a CSV
    if file.endswith('.csv'): 
        
        # 2. Use os.path.join for OS-agnostic path creation
        filepath = os.path.join('data', file)
        df = pd.read_csv(filepath) 
        print(df.shape) 
        
        # 3. Safely extract the filename without the extension
        table_name = os.path.splitext(file)[0]
        ingest_db(df, table_name, engine)
# Out:
# (206529, 9)
# (224489, 9)
# (2372474, 16)
# (12261, 9)
# (12825363, 14)
# (5543, 10)

# %%
# scripting for the database and continues data ingestion
def ingest_db(df, table_name, engine): 
    df.to_sql(table_name, con = engine, if_exists ='replace', index = False)

# %% [markdown]
# ### Logging

# %%
import pandas as pd 
import os 
from sqlalchemy import create_engine 
import logging
import time

# 1. FIX: Create the 'logs' directory if it doesn't exist yet
os.makedirs("logs", exist_ok=True)

logging.basicConfig( 
    filename="logs/ingestion_db.log", 
    level=logging.DEBUG, 
    format="%(asctime)s - %(levelname)s - %(message)s", 
    filemode="a" 
)

engine = create_engine('sqlite:///inventory.db')

def ingest_db(df, table_name, engine): 
    df.to_sql(table_name, con=engine, if_exists='replace', index=False)


def load_raw_data(): 
    '''this function will load the CSVs as dataframe and ingest into db''' 
    start = time.time() 
    
    # Applying the safer file handling practices
    for file in os.listdir('data'): 
        if file.endswith('.csv'): 
            filepath = os.path.join('data', file)
            df = pd.read_csv(filepath) 
            
            logging.info(f'Ingesting {file} in db') 
            table_name = os.path.splitext(file)[0]
            ingest_db(df, table_name, engine) 
            
    end = time.time() 
    total_time = (end - start) / 60 
    logging.info(' -- Ingestion Complete -- ')
    
    # 2. FIX: Moved this inside the function where total_time is defined
    logging.info(f'Total Time Taken: {total_time:.4f} minutes\n')


# 3. FIX: Corrected the dunder main syntax (needs double underscores)
if __name__ == '__main__': 
    load_raw_data()

# %%
import pandas as pd 
import os 
from sqlalchemy import create_engine 
import logging
import time

logging.basicConfig( filename="logs/ingestion_db.log", 
level=logging.DEBUG, 
format="%(asctime)s -%(levelname)s -%(message)s", 
filemode="a" )


engine = create_engine('sqlite:///inventory.db')


def ingest_db(df, table_name, engine): 
    df.to_sql(table_name, con = engine, if_exists ='replace', index = False)


def load_raw_data(): 
    '''this function will load the CSVs as dataframe and ingest into db''' 
    start = time.time() 
    for file in os. listdir('data'): 
        if '.csv' in file: 
            df = pd.read_csv('data/'+file) 
            logging.info(f'Ingesting {file} in db') 
            ingest_db(df, file[ :- 4], engine) 
            
    end = time.time() 
    total_time = (end - start)/60 
    logging. info(' -- Ingestion Complete- -')

logging.info(f'\nTotal Time Taken: {total_time} minutes')

if __name__=='_main_': 
    load_raw_data()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[25], line 7
#       4 import logging
#       5 import time
# ----> 7 logging.basicConfig( filename="logs/ingestion_db.log",
#       8 level=logging.DEBUG,
#       9 format="%(asctime)s -%(levelname)s -%(message)s",
#      10 filemode="a" )
#      13 engine = create_engine('sqlite:///inventory.db')
#      16 def ingest_db(df, table_name, engine):
#
# File c:\Users\6035s\anaconda3\envs\vendor\lib\logging\__init__.py:2040, in basicConfig(**kwargs)
#    2038     else:
#    2039         encoding = io.text_encoding(encoding)
# -> 2040     h = FileHandler(filename, mode,
#    2041                     encoding=encoding, errors=errors)
#    2042 else:
#    2043     stream = kwargs.pop("stream", None)
#
# ...
